# %%
# Dependencies
import pandas as pd
import requests
import json

# %%
EDRates_df = pd.read_csv('../../../data/EDRates35_wide.csv')
EDRates_df
# Out:
#     year  Apache  Cochise  Coconino  Gila  Graham  Greenlee  La_Paz  Maricopa  \
# 0   2011    22.2     48.6      19.4  44.4    41.3      43.7    37.9      25.8
# 1   2012    25.9     45.0      18.0  42.8    40.6      63.6    41.2      25.4
# 2   2013    21.7     42.8      17.1  39.6    28.5      52.3    25.8      24.4
# 3   2014    17.5     39.8      15.7  38.9    37.9      24.8    47.9      24.3
# 4   2015    23.1     37.5      18.8  34.3    45.5      43.8    32.7      25.3
# 5   2016    23.0     37.1      19.7  37.6    37.0      46.7    30.5      25.9
# 6   2017    19.4     38.1      17.7  44.3    54.8      54.0    23.4      26.1
# 7   2018    21.3     39.1      18.6  36.3    43.2      49.0    24.2      23.6
# 8   2019    25.4     36.8      16.1  43.3    33.2      36.6    45.6      24.0
# 9   2020    19.3     30.8      15.9  40.4    43.5      47.3    45.8      20.6
# 10  2021    24.0     31.8      16.9  44.5    29.2      41.2    44.2      21.0
#
# ...

# %%
Xheatdays_df = pd.read_csv('../../../data/ExtremeHeatDays_wide.csv')
Xheatdays_df
# Out:
#     year  Apache  Cochise  Coconino  Gila  Graham  Greenlee  La_Paz  Maricopa  \
# 0   2011      19       34        17    30      28        25      22        28
# 1   2012      19       25        20    27      22        22      15        21
# 2   2013      18       19        16    16      14        17      13        13
# 3   2014       5        4         4     3       3         4       3         2
# 4   2015      18       14        19    15      13        14      20        16
# 5   2016      16       19        17    22      19        18      27        23
# 6   2017      16       17        16    14      15        17      22        19
# 7   2018      31       18        28    24      22        19      19        19
# 8   2019      23       26        22    31      24        24      22        26
# 9   2020      38       35        36    48      48        46      39        45
# 10  2021      24       16        22    22      16        16      23        22
#
# ...

# %%
# Opening JSON file
f = open('arizona-with-county-boundaries_1085.geojson')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
for i in data['features']:
    county_data = i
  
# Closing file
f.close()

# %%
county_data
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-109.047, 33.776],
#     [-109.271, 33.777],
#     [-109.353, 33.778],
#     [-109.362, 33.755],
#     [-109.362, 33.746],
#     [-109.354, 33.733],
#     [-109.366, 33.731],
#     [-109.379, 33.725],
#     [-109.395, 33.722],
#     [-109.399, 33.715],
#     [-109.426, 33.717],
#     [-109.443, 33.716],
#     [-109.455, 33.704],
#     [-109.472, 33.702],
#     [-109.478, 33.691],
#     [-109.479, 33.669],
#     [-109.487, 33.664],
#     [-109.495, 33.652],
#     [-109.504, 33.644],
#     [-109.513, 33.642],
#     [-109.516, 33.636],
#     [-109.532, 33.619],
#     [-109.544, 33.617],
#     [-109.554, 33.62],
#     [-109.562, 33.626],
#     [-109.579, 33.616],
#     [-109.589, 33.616],
#     [-109.604, 33.612],
#     [-109.604, 33.601],
#     [-109.615, 33.594],
#     [-109.62, 33.584],
#     [-109.644, 33.586],
#     [-109.66, 33.584],
#     [-109.675, 33.573],
#     [-109.67, 33.558],
# ...

# %% [markdown]
# # Extreme Heat Days Dictionaries

# %%
Apache_XHD2011={}
Apache_XHD2012={}
Apache_XHD2013={}
Apache_XHD2014={}
Apache_XHD2015={}
Apache_XHD2016={}
Apache_XHD2017={}
Apache_XHD2018={}
Apache_XHD2019={}
Apache_XHD2020={}
Apache_XHD2021={}
for county in Xheatdays_df:
    Apache_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Apache[0]}
    Apache_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Apache[1]}
    Apache_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Apache[2]}
    Apache_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Apache[3]}
    Apache_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Apache[4]}
    Apache_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Apache[5]}
    Apache_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Apache[6]}
    Apache_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Apache[7]}
    Apache_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Apache[8]}
    Apache_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Apache[9]}
    Apache_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Apache[10]}
print(Apache_XHD2011, Apache_XHD2012, Apache_XHD2013, Apache_XHD2014,Apache_XHD2015, Apache_XHD2016, Apache_XHD2017, Apache_XHD2018, Apache_XHD2019, Apache_XHD2020, Apache_XHD2021)
# Out:
# {2011: 19} {2012: 19} {2013: 18} {2014: 5} {2015: 18} {2016: 16} {2017: 16} {2018: 31} {2019: 23} {2020: 38} {2021: 24}

# %%
def Merge(dict1, dict2, dict3, dict4, dict5, dict6, dict7, dict8, dict9, dict10, dict11):
    # create a new dictionary by merging the items of the two dictionaries using the union operator (|)
    merged = dict(dict1.items() | dict2.items() | dict3.items() | dict4.items() | dict5.items() | dict6.items() | dict7.items() | dict8.items() | dict9.items() | dict10.items() | dict11.items())
    # return the merged dictionary
    return merged

Apache_XHD = Merge(Apache_XHD2011, Apache_XHD2012, Apache_XHD2013, Apache_XHD2014, Apache_XHD2015, Apache_XHD2016, Apache_XHD2017, Apache_XHD2018, Apache_XHD2019, Apache_XHD2020, Apache_XHD2021)
Apache_XHD
# Out:
# {2016: 16,
#  2019: 23,
#  2020: 38,
#  2011: 19,
#  2012: 19,
#  2015: 18,
#  2013: 18,
#  2018: 31,
#  2021: 24,
#  2017: 16,
#  2014: 5}

# %%
Cochise_XHD2011={}
Cochise_XHD2012={}
Cochise_XHD2013={}
Cochise_XHD2014={}
Cochise_XHD2015={}
Cochise_XHD2016={}
Cochise_XHD2017={}
Cochise_XHD2018={}
Cochise_XHD2019={}
Cochise_XHD2020={}
Cochise_XHD2021={}
for county in Xheatdays_df:
    Cochise_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Cochise[0]}
    Cochise_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Cochise[1]}
    Cochise_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Cochise[2]}
    Cochise_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Cochise[3]}
    Cochise_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Cochise[4]}
    Cochise_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Cochise[5]}
    Cochise_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Cochise[6]}
    Cochise_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Cochise[7]}
    Cochise_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Cochise[8]}
    Cochise_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Cochise[9]}
    Cochise_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Cochise[10]}

Cochise_XHD = Merge(Cochise_XHD2011, Cochise_XHD2012, Cochise_XHD2013, Cochise_XHD2014, Cochise_XHD2015, Cochise_XHD2016, Cochise_XHD2017, Cochise_XHD2018, Cochise_XHD2019, Cochise_XHD2020, Cochise_XHD2021)
Cochise_XHD
# Out:
# {2020: 35,
#  2014: 4,
#  2021: 16,
#  2016: 19,
#  2019: 26,
#  2012: 25,
#  2017: 17,
#  2018: 18,
#  2011: 34,
#  2015: 14,
#  2013: 19}

# %%
Coconino_XHD2011={}
Coconino_XHD2012={}
Coconino_XHD2013={}
Coconino_XHD2014={}
Coconino_XHD2015={}
Coconino_XHD2016={}
Coconino_XHD2017={}
Coconino_XHD2018={}
Coconino_XHD2019={}
Coconino_XHD2020={}
Coconino_XHD2021={}
for county in Xheatdays_df:
    Coconino_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Coconino[0]}
    Coconino_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Coconino[1]}
    Coconino_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Coconino[2]}
    Coconino_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Coconino[3]}
    Coconino_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Coconino[4]}
    Coconino_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Coconino[5]}
    Coconino_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Coconino[6]}
    Coconino_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Coconino[7]}
    Coconino_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Coconino[8]}
    Coconino_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Coconino[9]}
    Coconino_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Coconino[10]}

Coconino_XHD = Merge(Coconino_XHD2011, Coconino_XHD2012, Coconino_XHD2013, Coconino_XHD2014, Coconino_XHD2015, Coconino_XHD2016, Coconino_XHD2017, Coconino_XHD2018, Coconino_XHD2019, Coconino_XHD2020, Coconino_XHD2021)
Coconino_XHD
# Out:
# {2014: 4,
#  2012: 20,
#  2015: 19,
#  2020: 36,
#  2021: 22,
#  2018: 28,
#  2019: 22,
#  2017: 16,
#  2013: 16,
#  2016: 17,
#  2011: 17}

# %%
Gila_XHD2011={}
Gila_XHD2012={}
Gila_XHD2013={}
Gila_XHD2014={}
Gila_XHD2015={}
Gila_XHD2016={}
Gila_XHD2017={}
Gila_XHD2018={}
Gila_XHD2019={}
Gila_XHD2020={}
Gila_XHD2021={}
for county in Xheatdays_df:
    Gila_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Gila[0]}
    Gila_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Gila[1]}
    Gila_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Gila[2]}
    Gila_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Gila[3]}
    Gila_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Gila[4]}
    Gila_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Gila[5]}
    Gila_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Gila[6]}
    Gila_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Gila[7]}
    Gila_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Gila[8]}
    Gila_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Gila[9]}
    Gila_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Gila[10]}

Gila_XHD = Merge(Gila_XHD2011, Gila_XHD2012, Gila_XHD2013, Gila_XHD2014, Gila_XHD2015, Gila_XHD2016, Gila_XHD2017, Gila_XHD2018, Gila_XHD2019, Gila_XHD2020, Gila_XHD2021)
Gila_XHD
# Out:
# {2019: 31,
#  2020: 48,
#  2021: 22,
#  2016: 22,
#  2013: 16,
#  2017: 14,
#  2015: 15,
#  2014: 3,
#  2011: 30,
#  2018: 24,
#  2012: 27}

# %%
Graham_XHD2011={}
Graham_XHD2012={}
Graham_XHD2013={}
Graham_XHD2014={}
Graham_XHD2015={}
Graham_XHD2016={}
Graham_XHD2017={}
Graham_XHD2018={}
Graham_XHD2019={}
Graham_XHD2020={}
Graham_XHD2021={}
for county in Xheatdays_df:
    Graham_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Graham[0]}
    Graham_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Graham[1]}
    Graham_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Graham[2]}
    Graham_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Graham[3]}
    Graham_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Graham[4]}
    Graham_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Graham[5]}
    Graham_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Graham[6]}
    Graham_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Graham[7]}
    Graham_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Graham[8]}
    Graham_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Graham[9]}
    Graham_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Graham[10]}

Graham_XHD = Merge(Graham_XHD2011, Graham_XHD2012, Graham_XHD2013, Graham_XHD2014, Graham_XHD2015, Graham_XHD2016, Graham_XHD2017, Graham_XHD2018, Graham_XHD2019, Graham_XHD2020, Graham_XHD2021)
Graham_XHD
# Out:
# {2021: 16,
#  2015: 13,
#  2020: 48,
#  2017: 15,
#  2016: 19,
#  2011: 28,
#  2012: 22,
#  2018: 22,
#  2014: 3,
#  2013: 14,
#  2019: 24}

# %%
Greenlee_XHD2011={}
Greenlee_XHD2012={}
Greenlee_XHD2013={}
Greenlee_XHD2014={}
Greenlee_XHD2015={}
Greenlee_XHD2016={}
Greenlee_XHD2017={}
Greenlee_XHD2018={}
Greenlee_XHD2019={}
Greenlee_XHD2020={}
Greenlee_XHD2021={}
for county in Xheatdays_df:
    Greenlee_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Greenlee[0]}
    Greenlee_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Greenlee[1]}
    Greenlee_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Greenlee[2]}
    Greenlee_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Greenlee[3]}
    Greenlee_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Greenlee[4]}
    Greenlee_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Greenlee[5]}
    Greenlee_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Greenlee[6]}
    Greenlee_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Greenlee[7]}
    Greenlee_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Greenlee[8]}
    Greenlee_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Greenlee[9]}
    Greenlee_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Greenlee[10]}
    
Greenlee_XHD = Merge(Greenlee_XHD2011, Greenlee_XHD2012, Greenlee_XHD2013, Greenlee_XHD2014, Greenlee_XHD2015, Greenlee_XHD2016, Greenlee_XHD2017, Greenlee_XHD2018, Greenlee_XHD2019, Greenlee_XHD2020, Greenlee_XHD2021)
Greenlee_XHD
# Out:
# {2021: 16,
#  2014: 4,
#  2011: 25,
#  2018: 19,
#  2016: 18,
#  2012: 22,
#  2017: 17,
#  2013: 17,
#  2015: 14,
#  2020: 46,
#  2019: 24}

# %%
La_Paz_XHD2011={}
La_Paz_XHD2012={}
La_Paz_XHD2013={}
La_Paz_XHD2014={}
La_Paz_XHD2015={}
La_Paz_XHD2016={}
La_Paz_XHD2017={}
La_Paz_XHD2018={}
La_Paz_XHD2019={}
La_Paz_XHD2020={}
La_Paz_XHD2021={}
for county in Xheatdays_df:
    La_Paz_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.La_Paz[0]}
    La_Paz_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.La_Paz[1]}
    La_Paz_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.La_Paz[2]}
    La_Paz_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.La_Paz[3]}
    La_Paz_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.La_Paz[4]}
    La_Paz_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.La_Paz[5]}
    La_Paz_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.La_Paz[6]}
    La_Paz_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.La_Paz[7]}
    La_Paz_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.La_Paz[8]}
    La_Paz_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.La_Paz[9]}
    La_Paz_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.La_Paz[10]}

La_Paz_XHD = Merge(La_Paz_XHD2011, La_Paz_XHD2012, La_Paz_XHD2013, La_Paz_XHD2014, La_Paz_XHD2015, La_Paz_XHD2016, La_Paz_XHD2017, La_Paz_XHD2018, La_Paz_XHD2019, La_Paz_XHD2020, La_Paz_XHD2021)
La_Paz_XHD
# Out:
# {2018: 19,
#  2011: 22,
#  2014: 3,
#  2019: 22,
#  2020: 39,
#  2012: 15,
#  2016: 27,
#  2021: 23,
#  2015: 20,
#  2013: 13,
#  2017: 22}

# %%
Maricopa_XHD2011={}
Maricopa_XHD2012={}
Maricopa_XHD2013={}
Maricopa_XHD2014={}
Maricopa_XHD2015={}
Maricopa_XHD2016={}
Maricopa_XHD2017={}
Maricopa_XHD2018={}
Maricopa_XHD2019={}
Maricopa_XHD2020={}
Maricopa_XHD2021={}
for county in Xheatdays_df:
    Maricopa_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Maricopa[0]}
    Maricopa_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Maricopa[1]}
    Maricopa_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Maricopa[2]}
    Maricopa_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Maricopa[3]}
    Maricopa_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Maricopa[4]}
    Maricopa_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Maricopa[5]}
    Maricopa_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Maricopa[6]}
    Maricopa_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Maricopa[7]}
    Maricopa_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Maricopa[8]}
    Maricopa_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Maricopa[9]}
    Maricopa_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Maricopa[10]}

Maricopa_XHD = Merge(Maricopa_XHD2011, Maricopa_XHD2012, Maricopa_XHD2013, Maricopa_XHD2014, Maricopa_XHD2015, Maricopa_XHD2016, Maricopa_XHD2017, Maricopa_XHD2018, Maricopa_XHD2019, Maricopa_XHD2020, Maricopa_XHD2021)
Maricopa_XHD
# Out:
# {2019: 26,
#  2021: 22,
#  2018: 19,
#  2011: 28,
#  2020: 45,
#  2012: 21,
#  2014: 2,
#  2017: 19,
#  2016: 23,
#  2013: 13,
#  2015: 16}

# %%
Mohave_XHD2011={}
Mohave_XHD2012={}
Mohave_XHD2013={}
Mohave_XHD2014={}
Mohave_XHD2015={}
Mohave_XHD2016={}
Mohave_XHD2017={}
Mohave_XHD2018={}
Mohave_XHD2019={}
Mohave_XHD2020={}
Mohave_XHD2021={}
for county in Xheatdays_df:
    Mohave_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Mohave[0]}
    Mohave_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Mohave[1]}
    Mohave_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Mohave[2]}
    Mohave_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Mohave[3]}
    Mohave_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Mohave[4]}
    Mohave_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Mohave[5]}
    Mohave_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Mohave[6]}
    Mohave_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Mohave[7]}
    Mohave_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Mohave[8]}
    Mohave_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Mohave[9]}
    Mohave_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Mohave[10]}

Mohave_XHD = Merge(Mohave_XHD2011, Mohave_XHD2012, Mohave_XHD2013, Mohave_XHD2014, Mohave_XHD2015, Mohave_XHD2016, Mohave_XHD2017, Mohave_XHD2018, Mohave_XHD2019, Mohave_XHD2020, Mohave_XHD2021)
Mohave_XHD
# Out:
# {2014: 4,
#  2016: 25,
#  2013: 18,
#  2015: 15,
#  2011: 18,
#  2018: 22,
#  2019: 22,
#  2020: 36,
#  2012: 14,
#  2017: 22,
#  2021: 26}

# %%
Navajo_XHD2011={}
Navajo_XHD2012={}
Navajo_XHD2013={}
Navajo_XHD2014={}
Navajo_XHD2015={}
Navajo_XHD2016={}
Navajo_XHD2017={}
Navajo_XHD2018={}
Navajo_XHD2019={}
Navajo_XHD2020={}
Navajo_XHD2021={}
for county in Xheatdays_df:
    Navajo_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Navajo[0]}
    Navajo_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Navajo[1]}
    Navajo_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Navajo[2]}
    Navajo_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Navajo[3]}
    Navajo_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Navajo[4]}
    Navajo_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Navajo[5]}
    Navajo_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Navajo[6]}
    Navajo_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Navajo[7]}
    Navajo_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Navajo[8]}
    Navajo_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Navajo[9]}
    Navajo_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Navajo[10]}

Navajo_XHD = Merge(Navajo_XHD2011, Navajo_XHD2012, Navajo_XHD2013, Navajo_XHD2014, Navajo_XHD2015, Navajo_XHD2016, Navajo_XHD2017, Navajo_XHD2018, Navajo_XHD2019, Navajo_XHD2020, Navajo_XHD2021)
Navajo_XHD
# Out:
# {2012: 20,
#  2015: 19,
#  2017: 15,
#  2018: 29,
#  2020: 41,
#  2014: 3,
#  2021: 21,
#  2011: 21,
#  2019: 27,
#  2013: 16,
#  2016: 20}

# %%
Pima_XHD2011={}
Pima_XHD2012={}
Pima_XHD2013={}
Pima_XHD2014={}
Pima_XHD2015={}
Pima_XHD2016={}
Pima_XHD2017={}
Pima_XHD2018={}
Pima_XHD2019={}
Pima_XHD2020={}
Pima_XHD2021={}
for county in Xheatdays_df:
    Pima_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Pima[0]}
    Pima_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Pima[1]}
    Pima_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Pima[2]}
    Pima_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Pima[3]}
    Pima_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Pima[4]}
    Pima_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Pima[5]}
    Pima_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Pima[6]}
    Pima_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Pima[7]}
    Pima_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Pima[8]}
    Pima_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Pima[9]}
    Pima_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Pima[10]}

Pima_XHD = Merge(Pima_XHD2011, Pima_XHD2012, Pima_XHD2013, Pima_XHD2014, Pima_XHD2015, Pima_XHD2016, Pima_XHD2017, Pima_XHD2018, Pima_XHD2019, Pima_XHD2020, Pima_XHD2021)
Pima_XHD
# Out:
# {2018: 17,
#  2021: 16,
#  2014: 4,
#  2015: 13,
#  2011: 32,
#  2020: 50,
#  2017: 17,
#  2013: 14,
#  2016: 21,
#  2019: 28,
#  2012: 27}

# %%
Pinal_XHD2011={}
Pinal_XHD2012={}
Pinal_XHD2013={}
Pinal_XHD2014={}
Pinal_XHD2015={}
Pinal_XHD2016={}
Pinal_XHD2017={}
Pinal_XHD2018={}
Pinal_XHD2019={}
Pinal_XHD2020={}
Pinal_XHD2021={}
for county in Xheatdays_df:
    Pinal_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Pinal[0]}
    Pinal_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Pinal[1]}
    Pinal_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Pinal[2]}
    Pinal_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Pinal[3]}
    Pinal_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Pinal[4]}
    Pinal_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Pinal[5]}
    Pinal_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Pinal[6]}
    Pinal_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Pinal[7]}
    Pinal_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Pinal[8]}
    Pinal_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Pinal[9]}
    Pinal_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Pinal[10]}

Pinal_XHD = Merge(Pinal_XHD2011, Pinal_XHD2012, Pinal_XHD2013, Pinal_XHD2014, Pinal_XHD2015, Pinal_XHD2016, Pinal_XHD2017, Pinal_XHD2018, Pinal_XHD2019, Pinal_XHD2020, Pinal_XHD2021)
Pinal_XHD
# Out:
# {2016: 26,
#  2019: 26,
#  2015: 15,
#  2011: 31,
#  2021: 21,
#  2020: 49,
#  2017: 16,
#  2014: 2,
#  2018: 21,
#  2012: 24,
#  2013: 13}

# %%
Santa_Cruz_XHD2011={}
Santa_Cruz_XHD2012={}
Santa_Cruz_XHD2013={}
Santa_Cruz_XHD2014={}
Santa_Cruz_XHD2015={}
Santa_Cruz_XHD2016={}
Santa_Cruz_XHD2017={}
Santa_Cruz_XHD2018={}
Santa_Cruz_XHD2019={}
Santa_Cruz_XHD2020={}
Santa_Cruz_XHD2021={}
for county in Xheatdays_df:
    Santa_Cruz_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Santa_Cruz[0]}
    Santa_Cruz_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Santa_Cruz[1]}
    Santa_Cruz_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Santa_Cruz[2]}
    Santa_Cruz_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Santa_Cruz[3]}
    Santa_Cruz_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Santa_Cruz[4]}
    Santa_Cruz_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Santa_Cruz[5]}
    Santa_Cruz_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Santa_Cruz[6]}
    Santa_Cruz_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Santa_Cruz[7]}
    Santa_Cruz_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Santa_Cruz[8]}
    Santa_Cruz_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Santa_Cruz[9]}
    Santa_Cruz_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Santa_Cruz[10]}

Santa_Cruz_XHD = Merge(Santa_Cruz_XHD2011, Santa_Cruz_XHD2012, Santa_Cruz_XHD2013, Santa_Cruz_XHD2014, Santa_Cruz_XHD2015, Santa_Cruz_XHD2016, Santa_Cruz_XHD2017, Santa_Cruz_XHD2018, Santa_Cruz_XHD2019, Santa_Cruz_XHD2020, Santa_Cruz_XHD2021)
Santa_Cruz_XHD
# Out:
# {2018: 17,
#  2017: 15,
#  2012: 29,
#  2015: 12,
#  2014: 6,
#  2011: 37,
#  2016: 21,
#  2013: 17,
#  2020: 33,
#  2021: 14,
#  2019: 24}

# %%
Yavapai_XHD2011={}
Yavapai_XHD2012={}
Yavapai_XHD2013={}
Yavapai_XHD2014={}
Yavapai_XHD2015={}
Yavapai_XHD2016={}
Yavapai_XHD2017={}
Yavapai_XHD2018={}
Yavapai_XHD2019={}
Yavapai_XHD2020={}
Yavapai_XHD2021={}
for county in Xheatdays_df:
    Yavapai_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Yavapai[0]}
    Yavapai_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Yavapai[1]}
    Yavapai_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Yavapai[2]}
    Yavapai_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Yavapai[3]}
    Yavapai_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Yavapai[4]}
    Yavapai_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Yavapai[5]}
    Yavapai_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Yavapai[6]}
    Yavapai_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Yavapai[7]}
    Yavapai_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Yavapai[8]}
    Yavapai_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Yavapai[9]}
    Yavapai_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Yavapai[10]}

Yavapai_XHD = Merge(Yavapai_XHD2011, Yavapai_XHD2012, Yavapai_XHD2013, Yavapai_XHD2014, Yavapai_XHD2015, Yavapai_XHD2016, Yavapai_XHD2017, Yavapai_XHD2018, Yavapai_XHD2019, Yavapai_XHD2020, Yavapai_XHD2021)
Yavapai_XHD
# Out:
# {2020: 35,
#  2019: 26,
#  2021: 22,
#  2016: 22,
#  2018: 19,
#  2014: 3,
#  2011: 24,
#  2017: 16,
#  2015: 17,
#  2012: 27,
#  2013: 19}

# %%
Yuma_XHD2011={}
Yuma_XHD2012={}
Yuma_XHD2013={}
Yuma_XHD2014={}
Yuma_XHD2015={}
Yuma_XHD2016={}
Yuma_XHD2017={}
Yuma_XHD2018={}
Yuma_XHD2019={}
Yuma_XHD2020={}
Yuma_XHD2021={}
for county in Xheatdays_df:
    Yuma_XHD2011 = {Xheatdays_df.year[0]: Xheatdays_df.Yuma[0]}
    Yuma_XHD2012 = {Xheatdays_df.year[1]: Xheatdays_df.Yuma[1]}
    Yuma_XHD2013 = {Xheatdays_df.year[2]: Xheatdays_df.Yuma[2]}
    Yuma_XHD2014 = {Xheatdays_df.year[3]: Xheatdays_df.Yuma[3]}
    Yuma_XHD2015 = {Xheatdays_df.year[4]: Xheatdays_df.Yuma[4]}
    Yuma_XHD2016 = {Xheatdays_df.year[5]: Xheatdays_df.Yuma[5]}
    Yuma_XHD2017 = {Xheatdays_df.year[6]: Xheatdays_df.Yuma[6]}
    Yuma_XHD2018 = {Xheatdays_df.year[7]: Xheatdays_df.Yuma[7]}
    Yuma_XHD2019 = {Xheatdays_df.year[8]: Xheatdays_df.Yuma[8]}
    Yuma_XHD2020 = {Xheatdays_df.year[9]: Xheatdays_df.Yuma[9]}
    Yuma_XHD2021 = {Xheatdays_df.year[10]: Xheatdays_df.Yuma[10]}

Yuma_XHD = Merge(Yuma_XHD2011, Yuma_XHD2012, Yuma_XHD2013, Yuma_XHD2014, Yuma_XHD2015, Yuma_XHD2016, Yuma_XHD2017, Yuma_XHD2018, Yuma_XHD2019, Yuma_XHD2020, Yuma_XHD2021)
Yuma_XHD
# Out:
# {2013: 12,
#  2017: 21,
#  2015: 22,
#  2011: 25,
#  2018: 19,
#  2014: 6,
#  2019: 22,
#  2021: 24,
#  2016: 24,
#  2020: 36,
#  2012: 17}

# %% [markdown]
# # ED Visit Rates Dictionaries

# %%
Apache_EDR2011={}
Apache_EDR2012={}
Apache_EDR2013={}
Apache_EDR2014={}
Apache_EDR2015={}
Apache_EDR2016={}
Apache_EDR2017={}
Apache_EDR2018={}
Apache_EDR2019={}
Apache_EDR2020={}
Apache_EDR2021={}
for county in EDRates_df:
    Apache_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Apache[0]}
    Apache_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Apache[1]}
    Apache_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Apache[2]}
    Apache_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Apache[3]}
    Apache_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Apache[4]}
    Apache_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Apache[5]}
    Apache_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Apache[6]}
    Apache_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Apache[7]}
    Apache_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Apache[8]}
    Apache_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Apache[9]}
    Apache_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Apache[10]}

Apache_EDR = Merge(Apache_EDR2011, Apache_EDR2012, Apache_EDR2013, Apache_EDR2014, Apache_EDR2015, Apache_EDR2016, Apache_EDR2017, Apache_EDR2018, Apache_EDR2019, Apache_EDR2020, Apache_EDR2021)

Cochise_EDR2011={}
Cochise_EDR2012={}
Cochise_EDR2013={}
Cochise_EDR2014={}
Cochise_EDR2015={}
Cochise_EDR2016={}
Cochise_EDR2017={}
Cochise_EDR2018={}
Cochise_EDR2019={}
Cochise_EDR2020={}
Cochise_EDR2021={}
for county in EDRates_df:
    Cochise_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Cochise[0]}
    Cochise_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Cochise[1]}
    Cochise_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Cochise[2]}
    Cochise_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Cochise[3]}
    Cochise_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Cochise[4]}
    Cochise_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Cochise[5]}
    Cochise_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Cochise[6]}
    Cochise_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Cochise[7]}
    Cochise_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Cochise[8]}
    Cochise_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Cochise[9]}
    Cochise_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Cochise[10]}

Cochise_EDR = Merge(Cochise_EDR2011, Cochise_EDR2012, Cochise_EDR2013, Cochise_EDR2014, Cochise_EDR2015, Cochise_EDR2016, Cochise_EDR2017, Cochise_EDR2018, Cochise_EDR2019, Cochise_EDR2020, Cochise_EDR2021)

Coconino_EDR2011={}
Coconino_EDR2012={}
Coconino_EDR2013={}
Coconino_EDR2014={}
Coconino_EDR2015={}
Coconino_EDR2016={}
Coconino_EDR2017={}
Coconino_EDR2018={}
Coconino_EDR2019={}
Coconino_EDR2020={}
Coconino_EDR2021={}
for county in EDRates_df:
    Coconino_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Coconino[0]}
    Coconino_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Coconino[1]}
    Coconino_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Coconino[2]}
    Coconino_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Coconino[3]}
    Coconino_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Coconino[4]}
    Coconino_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Coconino[5]}
    Coconino_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Coconino[6]}
    Coconino_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Coconino[7]}
    Coconino_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Coconino[8]}
    Coconino_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Coconino[9]}
    Coconino_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Coconino[10]}

Coconino_EDR = Merge(Coconino_EDR2011, Coconino_EDR2012, Coconino_EDR2013, Coconino_EDR2014, Coconino_EDR2015, Coconino_EDR2016, Coconino_EDR2017, Coconino_EDR2018, Coconino_EDR2019, Coconino_EDR2020, Coconino_EDR2021)

Gila_EDR2011={}
Gila_EDR2012={}
Gila_EDR2013={}
Gila_EDR2014={}
Gila_EDR2015={}
Gila_EDR2016={}
Gila_EDR2017={}
Gila_EDR2018={}
Gila_EDR2019={}
Gila_EDR2020={}
Gila_EDR2021={}
for county in EDRates_df:
    Gila_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Gila[0]}
    Gila_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Gila[1]}
    Gila_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Gila[2]}
    Gila_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Gila[3]}
    Gila_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Gila[4]}
    Gila_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Gila[5]}
    Gila_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Gila[6]}
    Gila_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Gila[7]}
    Gila_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Gila[8]}
    Gila_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Gila[9]}
    Gila_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Gila[10]}

Gila_EDR = Merge(Gila_EDR2011, Gila_EDR2012, Gila_EDR2013, Gila_EDR2014, Gila_EDR2015, Gila_EDR2016, Gila_EDR2017, Gila_EDR2018, Gila_EDR2019, Gila_EDR2020, Gila_EDR2021)

Greenlee_EDR2011={}
Greenlee_EDR2012={}
Greenlee_EDR2013={}
Greenlee_EDR2014={}
Greenlee_EDR2015={}
Greenlee_EDR2016={}
Greenlee_EDR2017={}
Greenlee_EDR2018={}
Greenlee_EDR2019={}
Greenlee_EDR2020={}
Greenlee_EDR2021={}
for county in EDRates_df:
    Greenlee_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Greenlee[0]}
    Greenlee_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Greenlee[1]}
    Greenlee_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Greenlee[2]}
    Greenlee_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Greenlee[3]}
    Greenlee_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Greenlee[4]}
    Greenlee_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Greenlee[5]}
    Greenlee_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Greenlee[6]}
    Greenlee_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Greenlee[7]}
    Greenlee_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Greenlee[8]}
    Greenlee_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Greenlee[9]}
    Greenlee_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Greenlee[10]}

Greenlee_EDR = Merge(Greenlee_EDR2011, Greenlee_EDR2012, Greenlee_EDR2013, Greenlee_EDR2014, Greenlee_EDR2015, Greenlee_EDR2016, Greenlee_EDR2017, Greenlee_EDR2018, Greenlee_EDR2019, Greenlee_EDR2020, Greenlee_EDR2021)

La_Paz_EDR2011={}
La_Paz_EDR2012={}
La_Paz_EDR2013={}
La_Paz_EDR2014={}
La_Paz_EDR2015={}
La_Paz_EDR2016={}
La_Paz_EDR2017={}
La_Paz_EDR2018={}
La_Paz_EDR2019={}
La_Paz_EDR2020={}
La_Paz_EDR2021={}
for county in EDRates_df:
    La_Paz_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.La_Paz[0]}
    La_Paz_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.La_Paz[1]}
    La_Paz_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.La_Paz[2]}
    La_Paz_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.La_Paz[3]}
    La_Paz_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.La_Paz[4]}
    La_Paz_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.La_Paz[5]}
    La_Paz_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.La_Paz[6]}
    La_Paz_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.La_Paz[7]}
    La_Paz_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.La_Paz[8]}
    La_Paz_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.La_Paz[9]}
    La_Paz_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.La_Paz[10]}

La_Paz_EDR = Merge(La_Paz_EDR2011, La_Paz_EDR2012, La_Paz_EDR2013, La_Paz_EDR2014, La_Paz_EDR2015, La_Paz_EDR2016, La_Paz_EDR2017, La_Paz_EDR2018, La_Paz_EDR2019, La_Paz_EDR2020, La_Paz_EDR2021)

Maricopa_EDR2011={}
Maricopa_EDR2012={}
Maricopa_EDR2013={}
Maricopa_EDR2014={}
Maricopa_EDR2015={}
Maricopa_EDR2016={}
Maricopa_EDR2017={}
Maricopa_EDR2018={}
Maricopa_EDR2019={}
Maricopa_EDR2020={}
Maricopa_EDR2021={}
for county in EDRates_df:
    Maricopa_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Maricopa[0]}
    Maricopa_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Maricopa[1]}
    Maricopa_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Maricopa[2]}
    Maricopa_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Maricopa[3]}
    Maricopa_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Maricopa[4]}
    Maricopa_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Maricopa[5]}
    Maricopa_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Maricopa[6]}
    Maricopa_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Maricopa[7]}
    Maricopa_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Maricopa[8]}
    Maricopa_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Maricopa[9]}
    Maricopa_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Maricopa[10]}

Maricopa_EDR = Merge(Maricopa_EDR2011, Maricopa_EDR2012, Maricopa_EDR2013, Maricopa_EDR2014, Maricopa_EDR2015, Maricopa_EDR2016, Maricopa_EDR2017, Maricopa_EDR2018, Maricopa_EDR2019, Maricopa_EDR2020, Maricopa_EDR2021)

Mohave_EDR2011={}
Mohave_EDR2012={}
Mohave_EDR2013={}
Mohave_EDR2014={}
Mohave_EDR2015={}
Mohave_EDR2016={}
Mohave_EDR2017={}
Mohave_EDR2018={}
Mohave_EDR2019={}
Mohave_EDR2020={}
Mohave_EDR2021={}
for county in EDRates_df:
    Mohave_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Mohave[0]}
    Mohave_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Mohave[1]}
    Mohave_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Mohave[2]}
    Mohave_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Mohave[3]}
    Mohave_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Mohave[4]}
    Mohave_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Mohave[5]}
    Mohave_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Mohave[6]}
    Mohave_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Mohave[7]}
    Mohave_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Mohave[8]}
    Mohave_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Mohave[9]}
    Mohave_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Mohave[10]}

Mohave_EDR = Merge(Mohave_EDR2011, Mohave_EDR2012, Mohave_EDR2013, Mohave_EDR2014, Mohave_EDR2015, Mohave_EDR2016, Mohave_EDR2017, Mohave_EDR2018, Mohave_EDR2019, Mohave_EDR2020, Mohave_EDR2021)

Navajo_EDR2011={}
Navajo_EDR2012={}
Navajo_EDR2013={}
Navajo_EDR2014={}
Navajo_EDR2015={}
Navajo_EDR2016={}
Navajo_EDR2017={}
Navajo_EDR2018={}
Navajo_EDR2019={}
Navajo_EDR2020={}
Navajo_EDR2021={}
for county in EDRates_df:
    Navajo_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Navajo[0]}
    Navajo_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Navajo[1]}
    Navajo_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Navajo[2]}
    Navajo_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Navajo[3]}
    Navajo_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Navajo[4]}
    Navajo_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Navajo[5]}
    Navajo_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Navajo[6]}
    Navajo_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Navajo[7]}
    Navajo_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Navajo[8]}
    Navajo_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Navajo[9]}
    Navajo_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Navajo[10]}

Navajo_EDR = Merge(Navajo_EDR2011, Navajo_EDR2012, Navajo_EDR2013, Navajo_EDR2014, Navajo_EDR2015, Navajo_EDR2016, Navajo_EDR2017, Navajo_EDR2018, Navajo_EDR2019, Navajo_EDR2020, Navajo_EDR2021)

Pima_EDR2011={}
Pima_EDR2012={}
Pima_EDR2013={}
Pima_EDR2014={}
Pima_EDR2015={}
Pima_EDR2016={}
Pima_EDR2017={}
Pima_EDR2018={}
Pima_EDR2019={}
Pima_EDR2020={}
Pima_EDR2021={}
for county in EDRates_df:
    Pima_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Pima[0]}
    Pima_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Pima[1]}
    Pima_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Pima[2]}
    Pima_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Pima[3]}
    Pima_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Pima[4]}
    Pima_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Pima[5]}
    Pima_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Pima[6]}
    Pima_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Pima[7]}
    Pima_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Pima[8]}
    Pima_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Pima[9]}
    Pima_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Pima[10]}

Pima_EDR = Merge(Pima_EDR2011, Pima_EDR2012, Pima_EDR2013, Pima_EDR2014, Pima_EDR2015, Pima_EDR2016, Pima_EDR2017, Pima_EDR2018, Pima_EDR2019, Pima_EDR2020, Pima_EDR2021)

Pinal_EDR2011={}
Pinal_EDR2012={}
Pinal_EDR2013={}
Pinal_EDR2014={}
Pinal_EDR2015={}
Pinal_EDR2016={}
Pinal_EDR2017={}
Pinal_EDR2018={}
Pinal_EDR2019={}
Pinal_EDR2020={}
Pinal_EDR2021={}
for county in EDRates_df:
    Pinal_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Pinal[0]}
    Pinal_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Pinal[1]}
    Pinal_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Pinal[2]}
    Pinal_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Pinal[3]}
    Pinal_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Pinal[4]}
    Pinal_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Pinal[5]}
    Pinal_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Pinal[6]}
    Pinal_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Pinal[7]}
    Pinal_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Pinal[8]}
    Pinal_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Pinal[9]}
    Pinal_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Pinal[10]}

Pinal_EDR = Merge(Pinal_EDR2011, Pinal_EDR2012, Pinal_EDR2013, Pinal_EDR2014, Pinal_EDR2015, Pinal_EDR2016, Pinal_EDR2017, Pinal_EDR2018, Pinal_EDR2019, Pinal_EDR2020, Pinal_EDR2021)

Santa_Cruz_EDR2011={}
Santa_Cruz_EDR2012={}
Santa_Cruz_EDR2013={}
Santa_Cruz_EDR2014={}
Santa_Cruz_EDR2015={}
Santa_Cruz_EDR2016={}
Santa_Cruz_EDR2017={}
Santa_Cruz_EDR2018={}
Santa_Cruz_EDR2019={}
Santa_Cruz_EDR2020={}
Santa_Cruz_EDR2021={}
for county in EDRates_df:
    Santa_Cruz_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Santa_Cruz[0]}
    Santa_Cruz_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Santa_Cruz[1]}
    Santa_Cruz_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Santa_Cruz[2]}
    Santa_Cruz_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Santa_Cruz[3]}
    Santa_Cruz_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Santa_Cruz[4]}
    Santa_Cruz_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Santa_Cruz[5]}
    Santa_Cruz_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Santa_Cruz[6]}
    Santa_Cruz_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Santa_Cruz[7]}
    Santa_Cruz_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Santa_Cruz[8]}
    Santa_Cruz_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Santa_Cruz[9]}
    Santa_Cruz_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Santa_Cruz[10]}

Santa_Cruz_EDR = Merge(Santa_Cruz_EDR2011, Santa_Cruz_EDR2012, Santa_Cruz_EDR2013, Santa_Cruz_EDR2014, Santa_Cruz_EDR2015, Santa_Cruz_EDR2016, Santa_Cruz_EDR2017, Santa_Cruz_EDR2018, Santa_Cruz_EDR2019, Santa_Cruz_EDR2020, Santa_Cruz_EDR2021)

Yavapai_EDR2011={}
Yavapai_EDR2012={}
Yavapai_EDR2013={}
Yavapai_EDR2014={}
Yavapai_EDR2015={}
Yavapai_EDR2016={}
Yavapai_EDR2017={}
Yavapai_EDR2018={}
Yavapai_EDR2019={}
Yavapai_EDR2020={}
Yavapai_EDR2021={}
for county in EDRates_df:
    Yavapai_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Yavapai[0]}
    Yavapai_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Yavapai[1]}
    Yavapai_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Yavapai[2]}
    Yavapai_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Yavapai[3]}
    Yavapai_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Yavapai[4]}
    Yavapai_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Yavapai[5]}
    Yavapai_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Yavapai[6]}
    Yavapai_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Yavapai[7]}
    Yavapai_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Yavapai[8]}
    Yavapai_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Yavapai[9]}
    Yavapai_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Yavapai[10]}

Yavapai_EDR = Merge(Yavapai_EDR2011, Yavapai_EDR2012, Yavapai_EDR2013, Yavapai_EDR2014, Yavapai_EDR2015, Yavapai_EDR2016, Yavapai_EDR2017, Yavapai_EDR2018, Yavapai_EDR2019, Yavapai_EDR2020, Yavapai_EDR2021)

Yuma_EDR2011={}
Yuma_EDR2012={}
Yuma_EDR2013={}
Yuma_EDR2014={}
Yuma_EDR2015={}
Yuma_EDR2016={}
Yuma_EDR2017={}
Yuma_EDR2018={}
Yuma_EDR2019={}
Yuma_EDR2020={}
Yuma_EDR2021={}
for county in EDRates_df:
    Yuma_EDR2011 = {Xheatdays_df.year[0]: Xheatdays_df.Yuma[0]}
    Yuma_EDR2012 = {Xheatdays_df.year[1]: Xheatdays_df.Yuma[1]}
    Yuma_EDR2013 = {Xheatdays_df.year[2]: Xheatdays_df.Yuma[2]}
    Yuma_EDR2014 = {Xheatdays_df.year[3]: Xheatdays_df.Yuma[3]}
    Yuma_EDR2015 = {Xheatdays_df.year[4]: Xheatdays_df.Yuma[4]}
    Yuma_EDR2016 = {Xheatdays_df.year[5]: Xheatdays_df.Yuma[5]}
    Yuma_EDR2017 = {Xheatdays_df.year[6]: Xheatdays_df.Yuma[6]}
    Yuma_EDR2018 = {Xheatdays_df.year[7]: Xheatdays_df.Yuma[7]}
    Yuma_EDR2019 = {Xheatdays_df.year[8]: Xheatdays_df.Yuma[8]}
    Yuma_EDR2020 = {Xheatdays_df.year[9]: Xheatdays_df.Yuma[9]}
    Yuma_EDR2021 = {Xheatdays_df.year[10]: Xheatdays_df.Yuma[10]}

Yuma_EDR = Merge(Yuma_EDR2011, Yuma_EDR2012, Yuma_EDR2013, Yuma_EDR2014, Yuma_EDR2015, Yuma_EDR2016, Yuma_EDR2017, Yuma_EDR2018, Yuma_EDR2019, Yuma_EDR2020, Yuma_EDR2021)
