# %%
# Dependencies
import requests
import json

# %% [markdown]
# # Age-adjusted Rate of Emergency Department Visits for HRI per 100,000 population

# %%
# URL for GET requests to retrieve data
version = "v1"
measureId = 440 # Requires a valid measureID
stratificationLevelId = 1 # Requires a valid stratificationLevelId.
geographicTypeIdFilter = "ALL" # Requires a valid geographicTypeID or ALL.
geographicItemsFilter = "ALL" # Filter to retrieve only certain geographicItems.
temporalTypeIdFilter = 1 # Requires a valid temporal type id matching temporal items (e.g., 1)
temporalItemsFilter = "2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021" # Requires valid temporal items entries (e.g., 2020) separated by comma.
isSmoothed = 0 # 0 not smoothed- most data isn't
getFullCoreHolder = 0 # Requires either a one or zero (true or false) for fetching the full core holder. 


# Build the endpoint URL
EDHRI_url = f"https://ephtracking.cdc.gov/apigateway/api/{version}/getCoreHolder/{measureId}/{stratificationLevelId}/{geographicTypeIdFilter}/{geographicItemsFilter}/{temporalTypeIdFilter}/{temporalItemsFilter}/{isSmoothed}/{getFullCoreHolder}" #{getFullCoreHolder}

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(EDHRI_url).json()

# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=False))
# Out:
# {
#     "legendResult": [],
#     "dataClassificationType": null,
#     "tableResultClass": "TableResult",
#     "tableReturnType": "tableResult",
#     "tableResult": [
#         {
#             "id": "1059676",
#             "geographicTypeId": 1,
#             "geo": "Alaska",
#             "geoId": "02",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2011",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2011,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2011",
#             "dataValue": "2.0",
#             "displayValue": "2.0",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Alaska",
#             "rollover": [
#                 "Age Adjusted Rate: 2.0"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059685",
#             "geographicTypeId": 1,
#             "geo": "Alaska",
#             "geoId": "02",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2012",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2012,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2012",
#             "dataValue": "0.4",
#             "displayValue": "0.4",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": 1,
#             "hatching": "Unstable",
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 20,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Alaska",
#             "rollover": [
#                 "Age Adjusted Rate: 0.4 (Unstable)"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059607",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2011",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2011,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2011",
#             "dataValue": "30.4",
#             "displayValue": "30.4",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 30.4"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059948",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2012",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2012,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2012",
#             "dataValue": "30.0",
#             "displayValue": "30.0",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 30.0"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059614",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2013",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2013,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2013",
#             "dataValue": "27.7",
#             "displayValue": "27.7",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 27.7"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059957",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2014",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2014,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2014",
#             "dataValue": "26.0",
#             "displayValue": "26.0",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 26.0"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059761",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2015",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2015,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2015",
#             "dataValue": "29.2",
#             "displayValue": "29.2",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 29.2"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059814",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2016",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2016,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2016",
#             "dataValue": "36.3",
#             "displayValue": "36.3",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 36.3"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059818",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2017",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2017,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2017",
#             "dataValue": "37.7",
#             "displayValue": "37.7",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 37.7"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059823",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2018",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2018,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2018",
#             "dataValue": "36.8",
#             "displayValue": "36.8",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 36.8"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059829",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2019",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2019,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2019",
#             "dataValue": "35.4",
#             "displayValue": "35.4",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 35.4"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059793",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2020",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2020,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2020",
#             "dataValue": "28.5",
#             "displayValue": "28.5",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 28.5"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059999",
#             "geographicTypeId": 1,
#             "geo": "Arizona",
#             "geoId": "04",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2021",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2021,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2021",
#             "dataValue": "33.9",
#             "displayValue": "33.9",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Arizona",
#             "rollover": [
#                 "Age Adjusted Rate: 33.9"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059940",
#             "geographicTypeId": 1,
#             "geo": "California",
#             "geoId": "06",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2011",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2011,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2011",
#             "dataValue": "10.2",
#             "displayValue": "10.2",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "California",
#             "rollover": [
#                 "Age Adjusted Rate: 10.2"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059609",
#             "geographicTypeId": 1,
#             "geo": "California",
#             "geoId": "06",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2012",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2012,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2012",
#             "dataValue": "13.0",
#             "displayValue": "13.0",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "California",
#             "rollover": [
#                 "Age Adjusted Rate: 13.0"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059734",
#             "geographicTypeId": 1,
#             "geo": "California",
#             "geoId": "06",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2013",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2013,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2013",
#             "dataValue": "13.2",
#             "displayValue": "13.2",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "California",
#             "rollover": [
#                 "Age Adjusted Rate: 13.2"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059744",
#             "geographicTypeId": 1,
#             "geo": "California",
#             "geoId": "06",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2014",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2014,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2014",
#             "dataValue": "13.1",
#             "displayValue": "13.1",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "California",
#             "rollover": [
#                 "Age Adjusted Rate: 13.1"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059754",
#             "geographicTypeId": 1,
#             "geo": "California",
#             "geoId": "06",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2015",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2015,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2015",
#             "dataValue": "13.4",
#             "displayValue": "13.4",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "California",
#             "rollover": [
#                 "Age Adjusted Rate: 13.4"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059850",
#             "geographicTypeId": 1,
#             "geo": "California",
#             "geoId": "06",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2016",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2016,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2016",
#             "dataValue": "13.5",
#             "displayValue": "13.5",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "California",
#             "rollover": [
#                 "Age Adjusted Rate: 13.5"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059856",
#             "geographicTypeId": 1,
#             "geo": "California",
#             "geoId": "06",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2017",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2017,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2017",
#             "dataValue": "20.0",
#             "displayValue": "20.0",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "California",
#             "rollover": [
#                 "Age Adjusted Rate: 20.0"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059981",
#             "geographicTypeId": 1,
#             "geo": "California",
#             "geoId": "06",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2018",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2018,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2018",
#             "dataValue": "15.4",
#             "displayValue": "15.4",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "California",
#             "rollover": [
#                 "Age Adjusted Rate: 15.4"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059785",
#             "geographicTypeId": 1,
#             "geo": "California",
#             "geoId": "06",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2019",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2019,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2019",
#             "dataValue": "13.2",
#             "displayValue": "13.2",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "California",
#             "rollover": [
#                 "Age Adjusted Rate: 13.2"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059804",
#             "geographicTypeId": 1,
#             "geo": "Colorado",
#             "geoId": "08",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2013",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2013,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2013",
#             "dataValue": "5.8",
#             "displayValue": "5.8",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Colorado",
#             "rollover": [
# ...
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Wisconsin",
#             "rollover": [
#                 "Age Adjusted Rate: 13.8"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059774",
#             "geographicTypeId": 1,
#             "geo": "Wisconsin",
#             "geoId": "55",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2016",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2016,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2016",
#             "dataValue": "18.4",
#             "displayValue": "18.4",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Wisconsin",
#             "rollover": [
#                 "Age Adjusted Rate: 18.4"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059862",
#             "geographicTypeId": 1,
#             "geo": "Wisconsin",
#             "geoId": "55",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2017",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2017,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2017",
#             "dataValue": "12.1",
#             "displayValue": "12.1",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Wisconsin",
#             "rollover": [
#                 "Age Adjusted Rate: 12.1"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059869",
#             "geographicTypeId": 1,
#             "geo": "Wisconsin",
#             "geoId": "55",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2018",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2018,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2018",
#             "dataValue": "21.6",
#             "displayValue": "21.6",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Wisconsin",
#             "rollover": [
#                 "Age Adjusted Rate: 21.6"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059877",
#             "geographicTypeId": 1,
#             "geo": "Wisconsin",
#             "geoId": "55",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2019",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2019,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2019",
#             "dataValue": "14.7",
#             "displayValue": "14.7",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Wisconsin",
#             "rollover": [
#                 "Age Adjusted Rate: 14.7"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059886",
#             "geographicTypeId": 1,
#             "geo": "Wisconsin",
#             "geoId": "55",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2020",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2020,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2020",
#             "dataValue": "13.2",
#             "displayValue": "13.2",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Wisconsin",
#             "rollover": [
#                 "Age Adjusted Rate: 13.2"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "1059890",
#             "geographicTypeId": 1,
#             "geo": "Wisconsin",
#             "geoId": "55",
#             "geoAbbreviation": "StateAbbreviation",
#             "parentGeographicTypeId": null,
#             "parentGeo": null,
#             "parentGeoId": null,
#             "parentGeoAbbreviation": null,
#             "calculationType": "Age Adjusted Rate",
#             "temporalTypeId": 1,
#             "temporal": "2021",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2021,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2021",
#             "dataValue": "15.2",
#             "displayValue": "15.2",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Wisconsin",
#             "rollover": [
#                 "Age Adjusted Rate: 15.2"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         }
#     ],
#     "healthImpactTableResult": [],
#     "climateChangeTableResult": [],
#     "dailyEstimatesTableResult": [],
#     "heatEpisodesTableResult": [],
#     "pmTableResult": [],
#     "regionPMTableResult": [],
#     "cwsTableResult": [],
#     "sampleSizeTableResult": [],
#     "stateMetadataTableResult": [],
#     "dailyTemperatureTableResult": [],
#     "benchmarkInformation": null,
#     "benchmarkResult": [],
#     "standard": [],
#     "aggregateResult": null,
#     "lookupList": {},
#     "measureInformationDTO": {
#         "measureInformation": {
#             "calculationId": 0,
#             "calculation": null,
#             "calculationTypeId": null,
#             "calculationType": null,
#             "calculationColumnName": null,
#             "parentTemporalType": null,
#             "temporalType": null,
#             "temporalTypeId": 0,
#             "temporalColumnName": null,
#             "temporalCount": 0,
#             "hasStability": null,
#             "smoothingType": null,
#             "precision": 0,
#             "hasConfidenceInterval": null,
#             "confidenceIntervalName": null,
#             "hasStandardError": null,
#             "standardErrorName": null,
#             "hasSecondaryValue": null,
#             "secondaryValueName": null,
#             "hasDescriptiveValue": null,
#             "descriptiveValueName": null,
#             "primaryLegendTitle": null,
#             "secondaryLegendTitle": null,
#             "colorCount": null,
#             "defaultBreakGroupCount": null,
#             "defaultDataClassificationTypeId": null,
#             "units": null,
#             "message": null,
#             "messageURL": null,
#             "activeMessage": null,
#             "categoryTypeId": null,
#             "temporalTextOverride": null
#         },
#         "tableDisplayDTO": [],
#         "chartDisplayDTO": [],
#         "mapDisplayDTO": [],
#         "chartAxisExceptionDTO": [],
#         "measureCalculationExceptionDTO": [],
#         "measureDisplayException": []
#     },
#     "measureStratificationLevel": {
#         "id": 0,
#         "measureId": 0,
#         "stratificationLevelId": 0,
#         "smoothingTypeId": 0,
#         "suppressionTypeId": 0
#     },
#     "publicAPIUrl": "/apigateway/api/v1/getCoreHolder/440/1/all/all/1/2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021/0/0",
#     "publicAPIServerUrl": "https://ephtracking.cdc.gov",
#     "fullPublicAPIUrl": "https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/440/1/all/all/1/2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021/0/0"
# }

# %% [markdown]
# ## API Max Temp Days

# %%
# URL for GET requests to retrieve data
version = "v1"
measureId = 423 # Requires a valid measureID
stratificationLevelId = 82 # Requires a valid stratificationLevelId.
geographicTypeIdFilter = 1 # Requires a valid geographicTypeID or ALL.
geographicItemsFilter = 4 # Filter to retrieve only certain geographicItems.
temporalTypeIdFilter = 1 # Requires a valid temporal type id matching temporal items (e.g., 1)
temporalItemsFilter = "2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011" # Requires valid temporal items entries (e.g., 2020) separated by comma.
isSmoothed = 0 # 0 not smoothed- most data isn't
getFullCoreHolder = 0 # Requires either a one or zero (true or false) for fetching the full core holder. 


# Build the endpoint URL
MaxTempDays_url = f"https://ephtracking.cdc.gov/apigateway/api/{version}/getCoreHolder/{measureId}/{stratificationLevelId}/{geographicTypeIdFilter}/{geographicItemsFilter}/{temporalTypeIdFilter}/{temporalItemsFilter}/{isSmoothed}/{getFullCoreHolder}?TemperatureHeatIndexId=1&RelativeThresholdId=1" #{getFullCoreHolder}

# %%
MaxTempDays_url
# Out:
# 'https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/423/82/1/4/1/2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011/0/0?TemperatureHeatIndexId=1&RelativeThresholdId=1'

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(MaxTempDays_url).json()

# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=False))
# Out:
# {
#     "legendResult": [],
#     "dataClassificationType": null,
#     "tableResultClass": "TableResult",
#     "tableReturnType": "tableResult",
#     "tableResult": [
#         {
#             "id": "6634743535",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2011",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2011,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2011",
#             "dataValue": "19",
#             "displayValue": "19",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 19"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6604106995",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2012",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2012,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2012",
#             "dataValue": "19",
#             "displayValue": "19",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 19"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591282212",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2013",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2013,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2013",
#             "dataValue": "18",
#             "displayValue": "18",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 18"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592853070",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2014",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2014,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2014",
#             "dataValue": "5",
#             "displayValue": "5",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 5"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591876124",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2015",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2015,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2015",
#             "dataValue": "18",
#             "displayValue": "18",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 18"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592748589",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2016",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2016,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2016",
#             "dataValue": "16",
#             "displayValue": "16",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 16"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592364789",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2017",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2017,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2017",
#             "dataValue": "16",
#             "displayValue": "16",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 16"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591660323",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2018",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2018,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2018",
#             "dataValue": "31",
#             "displayValue": "31",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 31"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592234751",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2019",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2019,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2019",
#             "dataValue": "23",
#             "displayValue": "23",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 23"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591408333",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2020",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2020,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2020",
#             "dataValue": "38",
#             "displayValue": "38",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 38"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591116361",
#             "geographicTypeId": 2,
#             "geo": "Apache",
#             "geoId": "04001",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2021",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2021,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2021",
#             "dataValue": "24",
#             "displayValue": "24",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Apache, AZ",
#             "rollover": [
#                 "Counts: 24"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592397528",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2011",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2011,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2011",
#             "dataValue": "34",
#             "displayValue": "34",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 34"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591376150",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2012",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2012,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2012",
#             "dataValue": "25",
#             "displayValue": "25",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 25"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592357976",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2013",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2013,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2013",
#             "dataValue": "19",
#             "displayValue": "19",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 19"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591026002",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2014",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2014,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2014",
#             "dataValue": "4",
#             "displayValue": "4",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 4"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592374909",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2015",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2015,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2015",
#             "dataValue": "14",
#             "displayValue": "14",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 14"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592552595",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2016",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2016,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2016",
#             "dataValue": "19",
#             "displayValue": "19",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 19"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591971565",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2017",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2017,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2017",
#             "dataValue": "17",
#             "displayValue": "17",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 17"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592424970",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2018",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2018,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2018",
#             "dataValue": "18",
#             "displayValue": "18",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 18"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591913673",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2019",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2019,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2019",
#             "dataValue": "26",
#             "displayValue": "26",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 26"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591179421",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2020",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2020,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2020",
#             "dataValue": "35",
#             "displayValue": "35",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 35"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592239558",
#             "geographicTypeId": 2,
#             "geo": "Cochise",
#             "geoId": "04003",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2021",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2021,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2021",
#             "dataValue": "16",
#             "displayValue": "16",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Cochise, AZ",
#             "rollover": [
#                 "Counts: 16"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592725975",
#             "geographicTypeId": 2,
#             "geo": "Coconino",
#             "geoId": "04005",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2011",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2011,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2011",
#             "dataValue": "17",
#             "displayValue": "17",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Coconino, AZ",
#             "rollover": [
#                 "Counts: 17"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591459064",
# ...
#                 "Counts: 22"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592215519",
#             "geographicTypeId": 2,
#             "geo": "Yuma",
#             "geoId": "04027",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2016",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2016,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2016",
#             "dataValue": "24",
#             "displayValue": "24",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Yuma, AZ",
#             "rollover": [
#                 "Counts: 24"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592780081",
#             "geographicTypeId": 2,
#             "geo": "Yuma",
#             "geoId": "04027",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2017",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2017,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2017",
#             "dataValue": "21",
#             "displayValue": "21",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Yuma, AZ",
#             "rollover": [
#                 "Counts: 21"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591172788",
#             "geographicTypeId": 2,
#             "geo": "Yuma",
#             "geoId": "04027",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2018",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2018,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2018",
#             "dataValue": "19",
#             "displayValue": "19",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Yuma, AZ",
#             "rollover": [
#                 "Counts: 19"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6592607333",
#             "geographicTypeId": 2,
#             "geo": "Yuma",
#             "geoId": "04027",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2019",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2019,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2019",
#             "dataValue": "22",
#             "displayValue": "22",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Yuma, AZ",
#             "rollover": [
#                 "Counts: 22"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591634152",
#             "geographicTypeId": 2,
#             "geo": "Yuma",
#             "geoId": "04027",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2020",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2020,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2020",
#             "dataValue": "36",
#             "displayValue": "36",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Yuma, AZ",
#             "rollover": [
#                 "Counts: 36"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         },
#         {
#             "id": "6591874111",
#             "geographicTypeId": 2,
#             "geo": "Yuma",
#             "geoId": "04027",
#             "geoAbbreviation": "CountyAbbreviation",
#             "parentGeographicTypeId": 1,
#             "parentGeo": "Arizona",
#             "parentGeoId": "04",
#             "parentGeoAbbreviation": "AZ",
#             "calculationType": "Counts",
#             "temporalTypeId": 1,
#             "temporal": "2021",
#             "temporalDescription": "Single Year",
#             "temporalColumnName": "ReportYear",
#             "temporalRollingColumnName": "RollingYearCount",
#             "temporalId": 2021,
#             "minimumTemporal": null,
#             "minimumTemporalId": null,
#             "parentTemporalTypeId": null,
#             "parentTemporalType": null,
#             "parentTemporal": null,
#             "parentTemporalId": null,
#             "year": "2021",
#             "dataValue": "24",
#             "displayValue": "24",
#             "groupById": "1",
#             "noDataId": -1,
#             "hatchingId": -1,
#             "hatching": null,
#             "suppressionFlag": "0",
#             "noDataBreakGroup": 0,
#             "confidenceIntervalLow": null,
#             "confidenceIntervalHigh": null,
#             "confidenceIntervalName": null,
#             "standardError": null,
#             "standardErrorName": null,
#             "secondaryValue": null,
#             "secondaryValueName": null,
#             "descriptiveValue": null,
#             "descriptiveValueName": null,
#             "includeDescriptiveValueName": null,
#             "categoryId": 0,
#             "category": null,
#             "categoryName": null,
#             "title": "Yuma, AZ",
#             "rollover": [
#                 "Counts: 24"
#             ],
#             "confidenceIntervalHighName": "",
#             "standardErrorDisplay": "",
#             "secondaryValueDisplay": "",
#             "confidenceIntervalDisplay": "",
#             "confidenceIntervalLowName": "",
#             "parentMinimumTemporalId": null,
#             "parentMinimumTemporal": null
#         }
#     ],
#     "healthImpactTableResult": [],
#     "climateChangeTableResult": [],
#     "dailyEstimatesTableResult": [],
#     "heatEpisodesTableResult": [],
#     "pmTableResult": [],
#     "regionPMTableResult": [],
#     "cwsTableResult": [],
#     "sampleSizeTableResult": [],
#     "stateMetadataTableResult": [],
#     "dailyTemperatureTableResult": [],
#     "benchmarkInformation": null,
#     "benchmarkResult": [],
#     "standard": [],
#     "aggregateResult": null,
#     "lookupList": {
#         "1": [
#             {
#                 "columnName": "TemperatureHeatIndexId",
#                 "itemName": "Heat Metric: Daily Maximum Temperature",
#                 "localId": 1,
#                 "uid": null,
#                 "stratificationTypeId": 25,
#                 "name": "Heat Metric"
#             },
#             {
#                 "columnName": "RelativeThresholdId",
#                 "itemName": "Relative Threshold: 90th Percentile",
#                 "localId": 1,
#                 "uid": null,
#                 "stratificationTypeId": 22,
#                 "name": "Relative Threshold"
#             }
#         ]
#     },
#     "measureInformationDTO": {
#         "measureInformation": {
#             "calculationId": 0,
#             "calculation": null,
#             "calculationTypeId": null,
#             "calculationType": null,
#             "calculationColumnName": null,
#             "parentTemporalType": null,
#             "temporalType": null,
#             "temporalTypeId": 0,
#             "temporalColumnName": null,
#             "temporalCount": 0,
#             "hasStability": null,
#             "smoothingType": null,
#             "precision": 0,
#             "hasConfidenceInterval": null,
#             "confidenceIntervalName": null,
#             "hasStandardError": null,
#             "standardErrorName": null,
#             "hasSecondaryValue": null,
#             "secondaryValueName": null,
#             "hasDescriptiveValue": null,
#             "descriptiveValueName": null,
#             "primaryLegendTitle": null,
#             "secondaryLegendTitle": null,
#             "colorCount": null,
#             "defaultBreakGroupCount": null,
#             "defaultDataClassificationTypeId": null,
#             "units": null,
#             "message": null,
#             "messageURL": null,
#             "activeMessage": null,
#             "categoryTypeId": null,
#             "temporalTextOverride": null
#         },
#         "tableDisplayDTO": [],
#         "chartDisplayDTO": [],
#         "mapDisplayDTO": [],
#         "chartAxisExceptionDTO": [],
#         "measureCalculationExceptionDTO": [],
#         "measureDisplayException": []
#     },
#     "measureStratificationLevel": {
#         "id": 0,
#         "measureId": 0,
#         "stratificationLevelId": 0,
#         "smoothingTypeId": 0,
#         "suppressionTypeId": 0
#     },
#     "publicAPIUrl": "/apigateway/api/v1/getCoreHolder/423/82/1/4/1/2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011/0/0?TemperatureHeatIndexId=1&RelativeThresholdId=1",
#     "publicAPIServerUrl": "https://ephtracking.cdc.gov",
#     "fullPublicAPIUrl": "https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/423/82/1/4/1/2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011/0/0?TemperatureHeatIndexId=1&RelativeThresholdId=1"
# }

# %% [markdown]
# ## Age-adjusted Rate of Hospitalizations for Heart Attack among People >=35 Years of Age per 10,000 Population

# %%
# URL for GET requests to retrieve data
version = "v1"
measureId = 108 # Requires a valid measureID
stratificationLevelId = 2 # Requires a valid stratificationLevelId.
geographicTypeIdFilter = "all" # Requires a valid geographicTypeID or ALL.
geographicItemsFilter = "all" # Filter to retrieve only certain geographicItems.
temporalTypeIdFilter = 1 # Requires a valid temporal type id matching temporal items (e.g., 1)
temporalItemsFilter = "2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011" # Requires valid temporal items entries (e.g., 2020) separated by comma.
isSmoothed = 0 # 0 not smoothed- most data isn't
getFullCoreHolder = 0 # Requires either a one or zero (true or false) for fetching the full core holder. 


# Build the endpoint URL
Hosp35_url = f"https://ephtracking.cdc.gov/apigateway/api/{version}/getCoreHolder/{measureId}/{stratificationLevelId}/{geographicTypeIdFilter}/{geographicItemsFilter}/{temporalTypeIdFilter}/{temporalItemsFilter}/{isSmoothed}/{getFullCoreHolder}"

#https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/108/2/all/all/1/2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011/0/0

# %%
Hosp35_url
# Out:
# 'https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/108/2/all/all/1/2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011/0/0'

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(Hosp35_url).json()

# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=False))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
