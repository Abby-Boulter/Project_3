# %%
# Dependencies
# import numpy as np
import pandas as pd
import datetime as dt
import requests
import json

# %% [markdown]
# # Extract: Data Pull

# %% [markdown]
# ## Extract Data & Clean

# %% [markdown]
# ### API Tracking data from CDC

# %% [markdown]
# #### Max temp days

# %%
# URL for GET requests to retrieve data
version = "v1"
measureId = 423 # Requires a valid measureID
stratificationLevelId = 82 # Requires a valid stratificationLevelId.
geographicTypeIdFilter = 1 # Requires a valid geographicTypeID or ALL.
geographicItemsFilter = 4 # Filter to retrieve only certain geographicItems.
temporalTypeIdFilter = 1 # Requires a valid temporal type id matching temporal items (e.g., 1)
temporalItemsFilter = "2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011" # Requires valid temporal items entries (e.g., 2020) separated by comma.
isSmoothed = 0 # 0 not smoothed- most data isn't
getFullCoreHolder = 0 # Requires either a one or zero (true or false) for fetching the full core holder. 


# Build the endpoint URL
MaxTempDays_url = f"https://ephtracking.cdc.gov/apigateway/api/{version}/getCoreHolder/{measureId}/{stratificationLevelId}/{geographicTypeIdFilter}/{geographicItemsFilter}/{temporalTypeIdFilter}/{temporalItemsFilter}/{isSmoothed}/{getFullCoreHolder}?TemperatureHeatIndexId=1&RelativeThresholdId=1" #{getFullCoreHolder}

response = requests.get(MaxTempDays_url).json()

# Isolate tableResult for easy reading
data = response["tableResult"]

#for index, element in enumerate(data):
#  print(index, ":", element)

# %%
# Create an empty list to hold summaries
summary_list = []

# loop through the data
for bob in data:
    county = bob["geo"]
    year = bob["temporal"]
    days = bob["dataValue"]
    
    # create summary dictionary
    summary_dict = {
        "county": county,
        "year": year,
        "ext_heat_days" : days
    }
    
    # Append the sumary dict to the list
    summary_list.append(summary_dict)

EHD = pd.DataFrame(summary_list) 
EHD
# Out:
#      county  year ext_heat_days
# 0    Apache  2011            19
# 1    Apache  2012            19
# 2    Apache  2013            18
# 3    Apache  2014             5
# 4    Apache  2015            18
# ..      ...   ...           ...
# 160    Yuma  2017            21
# 161    Yuma  2018            19
# 162    Yuma  2019            22
# 163    Yuma  2020            36
# 164    Yuma  2021            24
#
# [165 rows x 3 columns]

# %%
# Export the cleaned DataFrame as a CSV file. 
EHD.to_csv("data/ExtremeHeatDays.csv", encoding='utf8', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20968\3518191393.py in <module>
#       1 # Export the cleaned DataFrame as a CSV file.
# ----> 2 EHD.to_csv("data/ExtremeHeatDays.csv", encoding='utf8', index=False)
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1178             formatter=self.fmt,
#    1179         )
# -> 1180         csv_formatter.save()
#    1181
#    1182         if created_buffer:
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     239         """
#     240         # apply compression and byte/text conversion
# --> 241         with get_handle(
#     242             self.filepath_or_buffer,
#     243             self.mode,
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     692     # Only for write methods
#     693     if "r" not in mode and is_path:
# --> 694         check_parent_directory(str(handle))
#     695
#     696     if compression:
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\common.py in check_parent_directory(path)
#     566     parent = Path(path).parent
#     567     if not parent.is_dir():
# --> 568         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     569
#     570
#
# OSError: Cannot save file into a non-existent directory: 'data'

# %% [markdown]
# #### ED visits for over 35

# %%
# URL for GET requests to retrieve data
version = "v1"
measureId = 108 # Requires a valid measureID
stratificationLevelId = 2 # Requires a valid stratificationLevelId.
geographicTypeIdFilter = "all" # Requires a valid geographicTypeID or ALL.
geographicItemsFilter = "all" # Filter to retrieve only certain geographicItems.
temporalTypeIdFilter = 1 # Requires a valid temporal type id matching temporal items (e.g., 1)
temporalItemsFilter = "2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011" # Requires valid temporal items entries (e.g., 2020) separated by comma.
isSmoothed = 0 # 0 not smoothed- most data isn't
getFullCoreHolder = 0 # Requires either a one or zero (true or false) for fetching the full core holder. 


# Build the endpoint URL
Hosp35_url = f"https://ephtracking.cdc.gov/apigateway/api/{version}/getCoreHolder/{measureId}/{stratificationLevelId}/{geographicTypeIdFilter}/{geographicItemsFilter}/{temporalTypeIdFilter}/{temporalItemsFilter}/{isSmoothed}/{getFullCoreHolder}"

#https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/108/2/all/all/1/2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011/0/0

response = requests.get(Hosp35_url).json()

# Isolate tableResult for easy reading
data = response["tableResult"]

# %%
# Create an empty list to hold summaries
summary_list = []

# loop through the data
for bob in data:
    state = bob["parentGeoId"]
    county = bob["geo"]
    year = bob["temporal"]
    rate = bob["dataValue"]
    
    # create summary dictionary
    summary_dict = {
        "State" : state,
        "County": county,
        "Year": year,
        "Age Adjusted Rate ED" : rate
    }
    
    # Append the sumary dict to the list
    summary_list.append(summary_dict)

ED35 = pd.DataFrame(summary_list)  
ED35 #results all states
# Out:
#       State  County  Year Age Adjusted Rate ED
# 0        04  Apache  2011                 22.2
# 1        04  Apache  2012                 25.9
# 2        04  Apache  2013                 21.7
# 3        04  Apache  2014                 17.5
# 4        04  Apache  2015                 23.1
# ...     ...     ...   ...                  ...
# 16308    55    Wood  2017                 42.3
# 16309    55    Wood  2018                 41.0
# 16310    55    Wood  2019                 41.0
# 16311    55    Wood  2020                 33.0
# 16312    55    Wood  2021                 34.0
#
# [16313 rows x 4 columns]

# %%
#select rows where 'state' is AZ, 04
ED35 = ED35.loc[ED35['State'] == "04"]
ED35 = ED35.drop(columns=["State"])

# %%
ED35.rename(columns={'County': 'county', 'Year': 'year', 'Age Adjusted Rate ED': 'ed_rate_35'}, inplace=True)
ED35.head()
# Out:
#    county  year ed_rate_35
# 0  Apache  2011       22.2
# 1  Apache  2012       25.9
# 2  Apache  2013       21.7
# 3  Apache  2014       17.5
# 4  Apache  2015       23.1

# %%
ED35.to_csv("data/EDRates35.csv", encoding='utf8', index=False)

# %% [markdown]
# ### HRI Data from Arizona Department of Health Services (AZDHS)

# %% [markdown]
# #### ED visits

# %%
# File to Load
# Read the ED Visits data into a Pandas DataFrame
ed_visits_df = pd.read_csv('../data/AZ-EDVisits.csv')

# Get a brief summary of the ED visits DataFrame.
# ed_visits_df.info()

# %%
#drop duplicates & rows with GeogID 'ALL'
ed_visits_df = ed_visits_df.drop_duplicates(keep='first')
ed_visits_df = ed_visits_df[ed_visits_df['GeogID']!= 'ALL']
ed_visits_df.head()
# Out:
#          Name Domain  Indicator  Year GeogID  AgeGroup Gender Month  Measure  \
# 0      NAVAJO    HSI         89  2011   4017        20    ALL   ALL      440
# 2        PIMA    HSI         89  2011   4019        20    ALL   ALL      440
# 4       PINAL    HSI         89  2011   4021        20    ALL   ALL      440
# 6  SANTA CRUZ    HSI         89  2011   4023        20    ALL   ALL      440
# 8     YAVAPAI    HSI         89  2011   4025        20    ALL   ALL      440
#
#    Value                       ts  \
# 0  17.72  2023-04-18T10:21:46.240
# 2  20.12  2023-04-18T10:21:46.240
# 4  37.73  2023-04-18T10:21:46.240
# 6  17.72  2023-04-18T10:21:46.240
# 8  12.76  2023-04-18T10:21:46.240
#
#                                          measureName  \
# 0  Age-adjusted rate of emergency department visi...
# 2  Age-adjusted rate of emergency department visi...
# 4  Age-adjusted rate of emergency department visi...
# 6  Age-adjusted rate of emergency department visi...
# 8  Age-adjusted rate of emergency department visi...
#
#                              indicatorName      contentAreaName
# 0  Heat stress emergency department visits  Heat Stress Illness
# 2  Heat stress emergency department visits  Heat Stress Illness
# 4  Heat stress emergency department visits  Heat Stress Illness
# 6  Heat stress emergency department visits  Heat Stress Illness
# 8  Heat stress emergency department visits  Heat Stress Illness

# %%
#Pull Necessary columns and rename
ed_visits_df = ed_visits_df[['Name', 'Year', 'Value']]
ed_visits_df.rename(columns={'Name': 'county', 'Year': 'year', 'Value': 'ed_rate'}, inplace=True)
# ed_visits_df.head()

# %%
#sort and reset index
ed_visits_df = ed_visits_df.sort_values(by=['year', 'county'])
ed_visits_df = ed_visits_df.reset_index(drop=True)
ed_visits_df
# Out:
#          county  year  ed_rate
# 0       COCHISE  2011    23.72
# 1      COCONINO  2011    11.04
# 2          GILA  2011    29.87
# 3        GRAHAM  2011    38.41
# 4        LA PAZ  2011   144.96
# ..          ...   ...      ...
# 144        PIMA  2021    22.65
# 145       PINAL  2021    42.39
# 146  SANTA CRUZ  2021    40.66
# 147     YAVAPAI  2021    28.35
# 148        YUMA  2021    82.70
#
# [149 rows x 3 columns]

# %%
# Export the cleaned DataFrame as a CSV file. 
ed_visits_df.to_csv("data/cleaned-AZ-EDVisits.csv", encoding='utf8', index=False)

# %% [markdown]
# #### Hospitalization Data

# %%
# Read the Hospitalization data into a Pandas DataFrame
hosp_df = pd.read_csv('../data/AZ_Hospitalizations.csv')

# drop duplicates & rows with GeogID 'ALL'
hosp_df = hosp_df.drop_duplicates(keep='first')
hosp_df = hosp_df[hosp_df['GeogID']!= 'ALL']

# Pull Necessary columns and rename
hosp_df = hosp_df[['Name', 'Year', 'Value']]
hosp_df.rename(columns={'Name': 'county', 'Year': 'year', 'Value': 'hosp_rate'}, inplace=True)

# sort and reset index
hosp_df = hosp_df.sort_values(by=['year', 'county'])
hosp_df = hosp_df.reset_index(drop=True)

hosp_df
# Out:
#         county  year  hosp_rate
# 0         GILA  2011       0.00
# 1     GREENLEE  2011       0.00
# 2     MARICOPA  2011       8.73
# 3       MOHAVE  2011      11.43
# 4         PIMA  2011       4.79
# ..         ...   ...        ...
# 82        PIMA  2021       8.65
# 83       PINAL  2021       9.93
# 84  SANTA CRUZ  2021       0.00
# 85     YAVAPAI  2021       2.81
# 86        YUMA  2021      21.39
#
# [87 rows x 3 columns]

# %%
# Export the cleaned DataFrame as a CSV file. 
hosp_df.to_csv("data/cleaned_AZ_Hospitalizations.csv", encoding='utf8', index=False)

# %% [markdown]
# #### Vulnerability Data

# %%
# Read the Vulnerability data into a Pandas DataFrame
vulnerability_df = pd.read_csv('../data/AZ_Vulnerability.csv')

# drop duplicates & rows with GeogID 'ALL'
vulnerability_df = vulnerability_df.drop_duplicates(keep='first')
vulnerability_df = vulnerability_df[vulnerability_df['GeogID']!= 'ALL']

# Pull Necessary columns and rename
vulnerability_df = vulnerability_df[['Name', 'Year', 'Value']]
vulnerability_df.rename(columns={'Name': 'county', 'Year': 'year', 'Value': 'vul_rate'}, inplace=True)

# sort and reset index
vulnerability_df = vulnerability_df.sort_values(by=['year', 'county'])
vulnerability_df = vulnerability_df.reset_index(drop=True)
vulnerability_df
# Out:
#         county  year  vul_rate
# 0       APACHE  2010     0.993
# 1      COCHISE  2010     0.864
# 2     COCONINO  2010     0.819
# 3         GILA  2010     0.801
# 4       GRAHAM  2010     0.984
# 5     GREENLEE  2010     0.736
# 6       LA PAZ  2010     0.871
# 7     MARICOPA  2010     0.707
# 8       MOHAVE  2010     0.771
# 9       NAVAJO  2010     0.990
# 10        PIMA  2010     0.822
# 11       PINAL  2010     0.863
# 12  SANTA CRUZ  2010     0.954
# 13     YAVAPAI  2010     0.478
# 14        YUMA  2010     0.999
# 15      APACHE  2014     0.991
# 16     COCHISE  2014     0.906
# 17    COCONINO  2014     0.817
# 18        GILA  2014     0.882
# 19      GRAHAM  2014     0.952
# 20    GREENLEE  2014     0.696
# 21      LA PAZ  2014     0.856
# 22    MARICOPA  2014     0.669
# 23      MOHAVE  2014     0.877
# 24      NAVAJO  2014     0.996
# 25        PIMA  2014     0.840
# 26       PINAL  2014     0.848
# 27  SANTA CRUZ  2014     0.913
# 28     YAVAPAI  2014     0.599
# 29        YUMA  2014     0.993
# 30      APACHE  2016     0.989
# 31     COCHISE  2016     0.930
# 32    COCONINO  2016     0.764
# 33        GILA  2016     0.912
# 34      GRAHAM  2016     0.965
# 35    GREENLEE  2016     0.629
# 36      LA PAZ  2016     0.917
# 37    MARICOPA  2016     0.647
# 38      MOHAVE  2016     0.910
# 39      NAVAJO  2016     0.995
# 40        PIMA  2016     0.872
# 41       PINAL  2016     0.859
# 42  SANTA CRUZ  2016     0.915
# 43     YAVAPAI  2016     0.546
# 44        YUMA  2016     0.990

# %%
# Export the cleaned DataFrame as a CSV file. 
vulnerability_df.to_csv("data/cleaned_AZ_Vulnerability.csv", encoding='utf8', index=False)

# %% [markdown]
# ## Merge Data into CSV

# %%
# Combine the data into a single dataset.  
rates_df = pd.merge(ed_visits_df, hosp_df,how= "left",  on=['county','year'])
#rates_df

# Combine the data into a single dataset.  
df2 = pd.merge(rates_df, vulnerability_df, how= "left",  on=['county','year'])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   county     149 non-null    object
#  1   year       149 non-null    int64
#  2   ed_rate    149 non-null    float64
#  3   hosp_rate  76 non-null     float64
#  4   vul_rate   25 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 7.0+ KB

# %%
# Export the cleaned DataFrame as a CSV file. 
df2.to_csv("../data/HRI.csv", encoding='utf8', index=False)

# %% [markdown]
# ### Merge CSVs

# %%
# Read the HRI data into a Pandas DataFrame
HRI_df = pd.read_csv('../data/HRI.csv')
ExtHeat_df = pd.read_csv('../data/ExtremeHeatDays.csv')
ED35_df = pd.read_csv('../data/EDRates35.csv')

# %%
HRI_df
# Out:
#          county  year  ed_rate  hosp_rate  vul_rate
# 0       COCHISE  2011    23.72        NaN       NaN
# 1      COCONINO  2011    11.04        NaN       NaN
# 2          GILA  2011    29.87       0.00       NaN
# 3        GRAHAM  2011    38.41        NaN       NaN
# 4        LA PAZ  2011   144.96        NaN       NaN
# ..          ...   ...      ...        ...       ...
# 144        PIMA  2021    22.65       8.65       NaN
# 145       PINAL  2021    42.39       9.93       NaN
# 146  SANTA CRUZ  2021    40.66       0.00       NaN
# 147     YAVAPAI  2021    28.35       2.81       NaN
# 148        YUMA  2021    82.70      21.39       NaN
#
# [149 rows x 5 columns]

# %%
# Merge all into one combined file
df3= pd.merge(HRI_df, ExtHeat_df, how= "left",  on=['county','year'])
df3
# Out:
#          county  year  ed_rate  hosp_rate  vul_rate  ext_heat_days
# 0       COCHISE  2011    23.72        NaN       NaN            NaN
# 1      COCONINO  2011    11.04        NaN       NaN            NaN
# 2          GILA  2011    29.87       0.00       NaN            NaN
# 3        GRAHAM  2011    38.41        NaN       NaN            NaN
# 4        LA PAZ  2011   144.96        NaN       NaN            NaN
# ..          ...   ...      ...        ...       ...            ...
# 144        PIMA  2021    22.65       8.65       NaN            NaN
# 145       PINAL  2021    42.39       9.93       NaN            NaN
# 146  SANTA CRUZ  2021    40.66       0.00       NaN            NaN
# 147     YAVAPAI  2021    28.35       2.81       NaN            NaN
# 148        YUMA  2021    82.70      21.39       NaN            NaN
#
# [149 rows x 6 columns]

# %%
# Merge all into one combined file
df4= pd.merge(df3, ED35_df, how= "left",  on=['county','year'])
df4
# Out:
#          county  year  ed_rate  hosp_rate  vul_rate  ext_heat_days  ed_rate_35
# 0       COCHISE  2011    23.72        NaN       NaN            NaN         NaN
# 1      COCONINO  2011    11.04        NaN       NaN            NaN         NaN
# 2          GILA  2011    29.87       0.00       NaN            NaN         NaN
# 3        GRAHAM  2011    38.41        NaN       NaN            NaN         NaN
# 4        LA PAZ  2011   144.96        NaN       NaN            NaN         NaN
# ..          ...   ...      ...        ...       ...            ...         ...
# 144        PIMA  2021    22.65       8.65       NaN            NaN         NaN
# 145       PINAL  2021    42.39       9.93       NaN            NaN         NaN
# 146  SANTA CRUZ  2021    40.66       0.00       NaN            NaN         NaN
# 147     YAVAPAI  2021    28.35       2.81       NaN            NaN         NaN
# 148        YUMA  2021    82.70      21.39       NaN            NaN         NaN
#
# [149 rows x 7 columns]

# %%
df4['index'] = df4.index
print(df4)
# Out:
#          county  year  ed_rate  hosp_rate  vul_rate  ext_heat_days  \
# 0       COCHISE  2011    23.72        NaN       NaN            NaN
# 1      COCONINO  2011    11.04        NaN       NaN            NaN
# 2          GILA  2011    29.87       0.00       NaN            NaN
# 3        GRAHAM  2011    38.41        NaN       NaN            NaN
# 4        LA PAZ  2011   144.96        NaN       NaN            NaN
# ..          ...   ...      ...        ...       ...            ...
# 144        PIMA  2021    22.65       8.65       NaN            NaN
# 145       PINAL  2021    42.39       9.93       NaN            NaN
# 146  SANTA CRUZ  2021    40.66       0.00       NaN            NaN
# 147     YAVAPAI  2021    28.35       2.81       NaN            NaN
# 148        YUMA  2021    82.70      21.39       NaN            NaN
#
#      ed_rate_35  index
# 0           NaN      0
# 1           NaN      1
# 2           NaN      2
# 3           NaN      3
# 4           NaN      4
# ..          ...    ...
# 144         NaN    144
# 145         NaN    145
# 146         NaN    146
# 147         NaN    147
# 148         NaN    148
#
# [149 rows x 8 columns]

# %%
df4.fillna(method='ffill', inplace=True)

# %%
print(df4)
# Out:
#          county  year  ed_rate  hosp_rate  vul_rate  ext_heat_days  \
# 0       COCHISE  2011    23.72        NaN       NaN            NaN
# 1      COCONINO  2011    11.04        NaN       NaN            NaN
# 2          GILA  2011    29.87       0.00       NaN            NaN
# 3        GRAHAM  2011    38.41       0.00       NaN            NaN
# 4        LA PAZ  2011   144.96       0.00       NaN            NaN
# ..          ...   ...      ...        ...       ...            ...
# 144        PIMA  2021    22.65       8.65      0.99            NaN
# 145       PINAL  2021    42.39       9.93      0.99            NaN
# 146  SANTA CRUZ  2021    40.66       0.00      0.99            NaN
# 147     YAVAPAI  2021    28.35       2.81      0.99            NaN
# 148        YUMA  2021    82.70      21.39      0.99            NaN
#
#      ed_rate_35  index
# 0           NaN      0
# 1           NaN      1
# 2           NaN      2
# 3           NaN      3
# 4           NaN      4
# ..          ...    ...
# 144         NaN    144
# 145         NaN    145
# 146         NaN    146
# 147         NaN    147
# 148         NaN    148
#
# [149 rows x 8 columns]

# %%
# Export the cleaned DataFrame as a CSV file. 
#df4.to_csv("../data/AllHeat.csv", na_rep='NA', encoding='utf8', index=False)

# %% [markdown]
# # Load: SQLite database

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func, distinct

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float, Boolean

from pathlib import Path
import pandas as pd

# %%
Path('hri.sqlite').touch()

# %%
# create engine to HRI.sqlite
engine = create_engine("sqlite:///data/HRI.sqlite")

# %%
engine.execute('''CREATE TABLE vulnerability (county text, year int, vul_rate float)''')
engine.execute('''CREATE TABLE ed_visit_35 (county text, year int, ed_rate_35 float)''')

engine.execute('''CREATE TABLE hri (county text, year int, ED_rates float, Hosp_rates float, SVI float, HeatDays float)''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     326         """
# --> 327         return _ConnectionFairy._checkout(self)
#     328
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     893         if not fairy:
# --> 894             fairy = _ConnectionRecord.checkout(pool)
#     895
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     492     def checkout(cls, pool):
# --> 493         rec = pool._do_get()
#     494         try:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     255     def _do_get(self):
# --> 256         return self._create_connection()
#     257
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     272
# --> 273         return _ConnectionRecord(self)
#     274
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     387         if connect:
# --> 388             self.__connect()
#     389         self.finalize_callback = deque()
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     690             with util.safe_reraise():
# --> 691                 pool.logger.debug("Error on connect(): %s", e)
#     692         else:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     685             self.starttime = time.time()
# --> 686             self.dbapi_connection = connection = pool._invoke_creator(self)
#     687             pool.logger.debug("Created new connection %r", connection)
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     573                         return connection
# --> 574             return dialect.connect(*cargs, **cparams)
#     575
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     597         # inherits the docstring from interfaces.Dialect.connect
# --> 598         return self.dbapi.connect(*cargs, **cparams)
#     599
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20968\3834453944.py in <module>
# ----> 1 engine.execute('''CREATE TABLE vulnerability (county text, year int, vul_rate float)''')
#       2 engine.execute('''CREATE TABLE ed_visit_35 (county text, year int, ed_rate_35 float)''')
#       3
#       4 engine.execute('''CREATE TABLE hri (county text, year int, ED_rates float, Hosp_rates float, SVI float, HeatDays float)''')
#
# <string> in execute(self, statement, *multiparams, **params)
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     466         if not skip_warning:
#     467             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 468         return fn(*args, **kwargs)
#     469
#     470     doc = func.__doc__ is not None and func.__doc__ or ""
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3254
#    3255         """
# -> 3256         connection = self.connect(close_with_result=True)
#    3257         return connection.execute(statement, *multiparams, **params)
#    3258
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3313         """
#    3314
# -> 3315         return self._connection_cls(self, close_with_result=close_with_result)
#    3316
#    3317     @util.deprecated(
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3392
#    3393         """
# -> 3394         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3395
#    3396
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3362         except dialect.dbapi.Error as e:
#    3363             if connection is None:
# -> 3364                 Connection._handle_dbapi_exception_noconnection(
#    3365                     e, dialect, self
#    3366                 )
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2196             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2197         elif should_wrap:
# -> 2198             util.raise_(
#    2199                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2200             )
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3359         dialect = self.dialect
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#    3363             if connection is None:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     325
#     326         """
# --> 327         return _ConnectionFairy._checkout(self)
#     328
#     329     def _return_conn(self, record):
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     892     def _checkout(cls, pool, threadconns=None, fairy=None):
#     893         if not fairy:
# --> 894             fairy = _ConnectionRecord.checkout(pool)
#     895
#     896             fairy._pool = pool
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     @classmethod
#     492     def checkout(cls, pool):
# --> 493         rec = pool._do_get()
#     494         try:
#     495             dbapi_connection = rec.get_connection()
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     254
#     255     def _do_get(self):
# --> 256         return self._create_connection()
#     257
#     258     def recreate(self):
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     271         """Called by subclasses to create a new ConnectionRecord."""
#     272
# --> 273         return _ConnectionRecord(self)
#     274
#     275     def _invalidate(self, connection, exception=None, _checkin=True):
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     386         self.__pool = pool
#     387         if connect:
# --> 388             self.__connect()
#     389         self.finalize_callback = deque()
#     390
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     689         except BaseException as e:
#     690             with util.safe_reraise():
# --> 691                 pool.logger.debug("Error on connect(): %s", e)
#     692         else:
#     693             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     684         try:
#     685             self.starttime = time.time()
# --> 686             self.dbapi_connection = connection = pool._invoke_creator(self)
#     687             pool.logger.debug("Created new connection %r", connection)
#     688             self.fresh = True
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     572                     if connection is not None:
#     573                         return connection
# --> 574             return dialect.connect(*cargs, **cparams)
#     575
#     576         creator = pop_kwarg("creator", connect)
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     596     def connect(self, *cargs, **cparams):
#     597         # inherits the docstring from interfaces.Dialect.connect
# --> 598         return self.dbapi.connect(*cargs, **cparams)
#     599
#     600     def create_connect_args(self, url):
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# load the data into a Pandas DataFrame and write to sqlite table
hri = pd.read_csv('../data/HRI.csv')
hri.to_sql('hri', engine, if_exists='append', index = False)

vulnerability = pd.read_csv('../data/cleaned_AZ_Vulnerability.csv')
vulnerability.to_sql('vulnerability', engine, if_exists='append', index = False)

ed_visit_35 = pd.read_csv('../data/EDRates35.csv')
ed_visit_35.to_sql('ed_visit_35', engine, if_exists='append', index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     326         """
# --> 327         return _ConnectionFairy._checkout(self)
#     328
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     893         if not fairy:
# --> 894             fairy = _ConnectionRecord.checkout(pool)
#     895
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     492     def checkout(cls, pool):
# --> 493         rec = pool._do_get()
#     494         try:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     255     def _do_get(self):
# --> 256         return self._create_connection()
#     257
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     272
# --> 273         return _ConnectionRecord(self)
#     274
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     387         if connect:
# --> 388             self.__connect()
#     389         self.finalize_callback = deque()
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     690             with util.safe_reraise():
# --> 691                 pool.logger.debug("Error on connect(): %s", e)
#     692         else:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     685             self.starttime = time.time()
# --> 686             self.dbapi_connection = connection = pool._invoke_creator(self)
#     687             pool.logger.debug("Created new connection %r", connection)
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     573                         return connection
# --> 574             return dialect.connect(*cargs, **cparams)
#     575
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     597         # inherits the docstring from interfaces.Dialect.connect
# --> 598         return self.dbapi.connect(*cargs, **cparams)
#     599
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20968\1873990656.py in <module>
#       1 # load the data into a Pandas DataFrame and write to sqlite table
#       2 hri = pd.read_csv('../data/HRI.csv')
# ----> 3 hri.to_sql('hri', engine, if_exists='append', index = False)
#       4
#       5 vulnerability = pd.read_csv('../data/cleaned_AZ_Vulnerability.csv')
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2949         from pandas.io import sql
#    2950
# -> 2951         return sql.to_sql(
#    2952             self,
#    2953             name,
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     696         )
#     697
# --> 698     return pandas_sql.to_sql(
#     699         frame,
#     700         name,
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1730         sql_engine = get_engine(engine)
#    1731
# -> 1732         table = self.prep_table(
#    1733             frame=frame,
#    1734             name=name,
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1629             dtype=dtype,
#    1630         )
# -> 1631         table.create()
#    1632         return table
#    1633
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     830
#     831     def create(self):
# --> 832         if self.exists():
#     833             if self.if_exists == "fail":
#     834                 raise ValueError(f"Table '{self.name}' already exists.")
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\sql.py in exists(self)
#     814
#     815     def exists(self):
# --> 816         return self.pd_sql.has_table(self.name, self.schema)
#     817
#     818     def sql_schema(self):
#
# c:\Users\Noell\anaconda3\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1763             from sqlalchemy import inspect
#    1764
# -> 1765             insp = inspect(self.connectable)
#    1766             return insp.has_table(name, schema or self.meta.schema)
#    1767         else:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3313         """
#    3314
# -> 3315         return self._connection_cls(self, close_with_result=close_with_result)
#    3316
#    3317     @util.deprecated(
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3392
#    3393         """
# -> 3394         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3395
#    3396
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3362         except dialect.dbapi.Error as e:
#    3363             if connection is None:
# -> 3364                 Connection._handle_dbapi_exception_noconnection(
#    3365                     e, dialect, self
#    3366                 )
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2196             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2197         elif should_wrap:
# -> 2198             util.raise_(
#    2199                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2200             )
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3359         dialect = self.dialect
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#    3363             if connection is None:
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     325
#     326         """
# --> 327         return _ConnectionFairy._checkout(self)
#     328
#     329     def _return_conn(self, record):
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     892     def _checkout(cls, pool, threadconns=None, fairy=None):
#     893         if not fairy:
# --> 894             fairy = _ConnectionRecord.checkout(pool)
#     895
#     896             fairy._pool = pool
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     @classmethod
#     492     def checkout(cls, pool):
# --> 493         rec = pool._do_get()
#     494         try:
#     495             dbapi_connection = rec.get_connection()
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     254
#     255     def _do_get(self):
# --> 256         return self._create_connection()
#     257
#     258     def recreate(self):
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     271         """Called by subclasses to create a new ConnectionRecord."""
#     272
# --> 273         return _ConnectionRecord(self)
#     274
#     275     def _invalidate(self, connection, exception=None, _checkin=True):
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     386         self.__pool = pool
#     387         if connect:
# --> 388             self.__connect()
#     389         self.finalize_callback = deque()
#     390
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     689         except BaseException as e:
#     690             with util.safe_reraise():
# --> 691                 pool.logger.debug("Error on connect(): %s", e)
#     692         else:
#     693             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     684         try:
#     685             self.starttime = time.time()
# --> 686             self.dbapi_connection = connection = pool._invoke_creator(self)
#     687             pool.logger.debug("Created new connection %r", connection)
#     688             self.fresh = True
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     572                     if connection is not None:
#     573                         return connection
# --> 574             return dialect.connect(*cargs, **cparams)
#     575
#     576         creator = pop_kwarg("creator", connect)
#
# c:\Users\Noell\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     596     def connect(self, *cargs, **cparams):
#     597         # inherits the docstring from interfaces.Dialect.connect
# --> 598         return self.dbapi.connect(*cargs, **cparams)
#     599
#     600     def create_connect_args(self, url):
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
